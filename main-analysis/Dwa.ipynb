# %%
import numpy as np

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
from scipy.io import netcdf
import xarray as xr

# %%
test_sample = xr.open_dataset("tmax_1980subset.nc")

# %%
print(test_sample)
# Out:
# <xarray.Dataset> Size: 33MB
# Dimensions:  (lat: 135, lon: 166, time: 365)
# Coordinates:
#   * lat      (lat) float64 1kB 42.82 42.83 42.84 42.85 ... 44.14 44.15 44.16
#   * lon      (lon) float64 1kB -80.32 -80.31 -80.3 ... -78.69 -78.68 -78.67
#   * time     (time) datetime64[ns] 3kB 1980-01-01T12:00:00 ... 1980-12-30T12:...
# Data variables:
#     tmax     (time, lat, lon) float32 33MB ...
# Attributes:
#     regrid_method:  bilinear

# %%
test_sample.isel(time = 100).tmax.plot()
