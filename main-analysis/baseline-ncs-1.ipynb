# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import xarray as xr
import rioxarray as rxr
import cartopy.crs as ccrs
import cartopy.feature as cfeature
# import xesmf as xe
import xclim.sdba as sdba

# %%
ds_tmax = xr.open_dataset("baseline_hotdays.nc")
ds_tmax['lon'] = ds_tmax['lon'] - 360

# %%
# print(ds_tmax['lon']-360)
# print(ds_tmax['lat'])
# print(ds_tmax['scen'])
# print(ds_tmax)

# %%
toronto_map = gpd.read_file('toronto_neighbourhood_shape.shp', crs="epsg:4326")

fig, ax = plt.subplots(figsize=(10, 6))
ds_tmax.scen.plot(x = 'lon', y = 'lat', cbar_kwargs = {'label' : 'number of days over 30 degrees'})
toronto = toronto_map.plot(ax=ax, edgecolor='black', facecolor='none')

ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_title('Simulated Historical Heat Map of Toronto')
plt.savefig('historical-map.pdf')
plt.show()
